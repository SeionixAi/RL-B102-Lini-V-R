# %% [markdown]
# ## 1. Create DataFrame

# %%
import pandas as pd

# %%
data = {
    "Name":["Alice", "Bob", "Charlie"],
    "Age":[22,24,23],
    "Marks":[85,90,88]
}

df=pd.DataFrame(data)
print(data)
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [22, 24, 23], 'Marks': [85, 90, 88]}

# %% [markdown]
# ## 2. Read csv

# %%
daf=pd.read_csv("data.csv")
print(df.head())

# %% [markdown]
# ## 3. Basic Operations

# %%
print(df["Age"].mean())
print(df["Marks"].max())
# Out:
# 23.0
# 90

# %% [markdown]
# ## 4. Filtering

# %%
print(df[df["Marks"] > 85])
# Out:
#       Name  Age  Marks
# 1      Bob   24     90
# 2  Charlie   23     88
